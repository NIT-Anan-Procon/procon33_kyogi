# %%
#CHECK SHAZAM

from os.path import dirname, join as pjoin
from scipy.io import wavfile
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from scipy.io.wavfile import write

wav_fname = 'Q_E01.wav'
samplerate, data = wavfile.read(wav_fname)
length = data.shape[0] / samplerate

time = np.linspace(0., length, data.shape[0])

datas = []
for num in data:
        if(num > 4000 or num < -4000):
          datas.append(num)
        else :
          datas.append(0)
            
datass = np.array(datas)

plt.plot(time, data, label="Q_E01")
plt.plot(time, datass, label="Q_E01_peaks")

plt.legend()
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
plt.show()

write("try.wav", samplerate, datass.astype(np.int16))

# %% [markdown]
# # Main Idea (TOO HARD :")
#
# there is a possibility that the beginning and ending part of the sample file is cut.
# they will split the mondai data into minimum 2 parts and maximum 5 parts. with minimum duration of 0.5s.
# time limit is between 2-10 minutes
#
# 1. measure the length of the mondai data
# 2. do rfft to get the frequency domain version of the mondai file
# 3. reshape every other signal to the size of the mondai file
#
# # New Idea
#
# 1. make an identifier (refering to shazam technique) for every sample file
# 2. make an identifier file for the mondai file
# 3.

# %%
#SIMILAR TO SHAZAM TYPE

from os.path import dirname, join as pjoin
from scipy.io import wavfile
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from scipy.io.wavfile import write

#print(os.getcwd())
#os.chdir('\\Users\\alcan\\anaconda3\\Procon')

samplerate, data = wavfile.read('Q_E04.wav')
length = data.shape[0] / samplerate
time = np.linspace(0., length, data.shape[0])

samplerate2, data2 = wavfile.read('E05.wav')
data2_resize = data2.copy()
data2_resize.resize(data.shape[0],refcheck=False)
length2 = data2_resize.shape[0] / samplerate2
time2 = np.linspace(0., length2, data2_resize.shape[0])

datas = []
datas2 = []

for num in data:
        if(num > 4000 or num < -4000):
          datas.append(num)
        else :
          datas.append(0)
        
for num in data2_resize:
        if(num > 4000 or num < -4000):
          datas2.append(num)
        else :
          datas2.append(0)
            
datass = np.array(datas)
datass2 = np.array(datas2)

corr_coeff = np.corrcoef(datass, datass2)

#plt.xlim([3.75, 4.25])

print(corr_coeff)
plt.plot(time, datass, label="Q_E01")
plt.plot(time, datass2, label="E_01")

plt.legend()
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
plt.show()

#write("try.wav", samplerate, datass.astype(np.int16))

# %%
#CORRELATION COEFFICIENT

from os.path import dirname, join as pjoin
from scipy.io import wavfile
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from scipy.io.wavfile import write
from scipy import signal

#print(os.getcwd())
#os.chdir('\\Users\\alcan\\anaconda3\\Procon')

samplerate, data = wavfile.read('E01.wav')
length = data.shape[0] / samplerate
time = np.linspace(0., length, data.shape[0])

samplerate2, data2 = wavfile.read('E01.wav')
data2_resize = data2.copy()
data2_resize.resize(data.shape[0],refcheck=False)
length2 = data2_resize.shape[0] / samplerate2
time2 = np.linspace(0., length2, data2_resize.shape[0])           

corr = signal.correlate(data, data2_resize, method = 'fft')
lags = signal.correlation_lags(len(data2_resize), len(data))
#corr /= np.max(corr)

#corr = np.correlate(data, data2_resize, mode = "same")
best_cor = 0 #highest value
best_cor_loc = 0 #lag
temp = 0



for num in corr:
    if(num > best_cor):
        best_cor = num
        best_cor_loc = temp
    temp = temp + 1

print(corr)
print(lags)

#corr_coeff = np.corrcoef(data, data2_resize)
#corr = scipy.signal.correlate(data, data2_resize, mode='full')
print(best_cor, best_cor_loc)

plt.plot(time, data, label="Q_E01")
plt.plot(time, data2_resize, label="Q_E01_peaks")

plt.legend()
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
plt.show()
#print(corr)

#write("try.wav", samplerate, datass.astype(np.int16))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-66ab4e87af48> in <module>
#      38         best_cor_loc = temp
#      39     temp = temp + 1
# ---> 40 corr /= int(best_cor-1)
#      41
#      42 print(corr)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc true_divide

# %%
#ITERATE FOR EVERY FILE IN A FOLDER

import os
# assign directory
#print(os.getcwd())
#os.chdir('\sample_Q_E01')
 
# iterate over files in
# that directory
for filename in os.listdir(os.getcwd()):
    f = os.path.join(os.getcwd(), filename)
    # checking if it is a file
    if os.path.isfile(f):
        print(f)

# %%
#CHECK EACH 読みデータ TO THE PROBLEM BY COMPARING AMPLITUDE

from os.path import dirname, join as pjoin
from scipy.io import wavfile
import scipy.io
import matplotlib.pyplot as plt
import numpy as np

wav_fname = 'Q_E01.wav'
samplerate, data = wavfile.read(wav_fname)
length = data.shape[0] / samplerate
time = np.linspace(0., length, data.shape[0])

wav_fname2 = 'E01.wav'
samplerate2, data2 = wavfile.read(wav_fname2)
data2_resize = data2.copy()
data2_resize.resize(data.shape[0],refcheck=False)
length2 = data2_resize.shape[0] / samplerate2
time2 = np.linspace(0., length2, data2_resize.shape[0])

wav_fname3 = 'E02.wav'
samplerate3, data3 = wavfile.read(wav_fname3)
data3_resize = data3.copy()
data3_resize.resize(data.shape,refcheck=False)
length3 = data3_resize.shape[0] / samplerate3
time3 = np.linspace(0., length3, data3_resize.shape[0])

wav_fname4 = 'E03.wav'
samplerate4, data4 = wavfile.read(wav_fname4)
data4_resize = data4.copy()
data4_resize.resize(data.shape,refcheck=False)
length4 = data4_resize.shape[0] / samplerate4
time4 = np.linspace(0., length4, data4_resize.shape[0])
             
plt.plot(time, data, label="problem")
#plt.plot(time2, data2_resize, label="E01")
#plt.plot(time3, data3_resize, label="E02")
#plt.plot(time4, data4_resize, label="E03")

#plt.xlim([0, 0.2])

plt.legend()
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
plt.show()

# %%
#FFT

from os.path import dirname, join as pjoin
from scipy.io import wavfile
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from scipy.fft import rfft, rfftfreq, irfft #real fft which only process the real portion of the fft result

wav_fname = 'Q_E01.wav'
samplerate, data = wavfile.read(wav_fname)
length = data.shape[0] / samplerate
time = np.linspace(0., length, data.shape[0])

wav_fname2 = 'E01.wav'
samplerate2, data2 = wavfile.read(wav_fname2)
np.resize(data2,data.shape)
length2 = data2_resize.shape[0] / samplerate2
time2 = np.linspace(0., length2, data2.shape[0])

wav_fname3 = 'E02.wav'
samplerate3, data3 = wavfile.read(wav_fname3)
data3_resize = data3.copy()
data3_resize.resize(data.shape,refcheck=False)
length3 = data3_resize.shape[0] / samplerate3
time3 = np.linspace(0., length3, data3_resize.shape[0])

wav_fname4 = 'E03.wav'
samplerate4, data4 = wavfile.read(wav_fname4)
data4_resize = data4.copy()
data4_resize.resize(data.shape,refcheck=False)
length4 = data4_resize.shape[0] / samplerate4
time4 = np.linspace(0., length4, data4_resize.shape[0])

# Number of sample points
N = int(samplerate*length)
# sample spacing
T = 1.0 / samplerate

yf = rfft(data)
xf = rfftfreq(N, T)

yf2 = rfft(data2_resize)
yf3 = rfft(data3_resize)
yf4 = rfft(data4_resize)

add = np.add(data2_resize,data3_resize)
add2 = np.add(data4_resize,add)

yf_add = rfft(add2)


plt.plot(xf, np.abs(yf), label="problem")
plt.plot(xf, np.abs(yf_add), label="total")

#plt.plot(xf, np.abs(yf2), label="E01")
#plt.plot(xf, np.abs(yf3), label="E02")
#plt.plot(xf, np.abs(yf4), label="E03")

#plt.xlim([160, 680])

plt.grid()
plt.legend()
plt.xlabel("frequency [Hz]")
plt.ylabel("Power")
plt.show()

# %%
#COMPARING THE FFT OF THE 読みデータ TO THE FFT OF THE PROBLEM

from os.path import dirname, join as pjoin
from scipy.io import wavfile
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
from scipy.fft import rfft, rfftfreq, irfft #real fft which only process the real portion of the fft result

wav_fname = 'problem3.wav'
samplerate, data = wavfile.read(wav_fname)
length = data.shape[0] / samplerate
time = np.linspace(0., length, data.shape[0])

wav_fname2 = 'E01.wav'
samplerate2, data2 = wavfile.read(wav_fname2)
data2_resize = data2.copy()
data2_resize.resize(data.shape,refcheck=False)
length2 = data2_resize.shape[0] / samplerate
time2 = np.linspace(0., length2, data2_resize.shape[0])

wav_fname3 = 'E02.wav'
samplerate3, data3 = wavfile.read(wav_fname3)
data3_resize = data3.copy()
data3_resize.resize(data.shape,refcheck=False)
length3 = data3_resize.shape[0] / samplerate
time3 = np.linspace(0., length3, data3_resize.shape[0])

wav_fname4 = 'E03.wav'
samplerate4, data4 = wavfile.read(wav_fname4)
data4_resize = data4.copy()
data4_resize.resize(data.shape,refcheck=False)
length4 = data4_resize.shape[0] / samplerate
time4 = np.linspace(0., length4, data4_resize.shape[0])

wav_fname5 = 'E04.wav'
samplerate5, data5 = wavfile.read(wav_fname5)
data5_resize = data5.copy()
data5_resize.resize(data.shape,refcheck=False)
length5 = data5_resize.shape[0] / samplerate
time5 = np.linspace(0., length5, data5_resize.shape[0])

wav_fname6 = 'E05.wav'
samplerate6, data6 = wavfile.read(wav_fname6)
data6_resize = data6.copy()
data6_resize.resize(data.shape,refcheck=False)
length6 = data6_resize.shape[0] / samplerate
time6 = np.linspace(0., length6, data6_resize.shape[0])

# Number of sample points
N = int(samplerate*length)
# sample spacing
T = 1.0 / samplerate

yf = rfft(data)
xf = rfftfreq(N, T)

yf2 = rfft(data2_resize)
yf3 = rfft(data3_resize)
yf4 = rfft(data4_resize)
yf5 = rfft(data5_resize)
yf6 = rfft(data6_resize)

add = np.add(data2_resize,data3_resize)
add2 = np.add(data4_resize,add)
add3 = np.add(data5_resize,add)
add4 = np.add(data6_resize,add)

yf_add = rfft(add4)


plt.plot(xf, np.abs(yf), label="problem")
plt.plot(xf, np.abs(yf_add), label="total")

#plt.plot(xf, np.abs(yf2), label="E01")
#plt.plot(xf, np.abs(yf3), label="E02")
#plt.plot(xf, np.abs(yf4), label="E03")

#plt.xlim([160, 680])

plt.grid()
plt.legend()
plt.xlabel("frequency [Hz]")
plt.ylabel("Power")
plt.show()

# %%
from os.path import dirname, join as pjoin
from scipy.io import wavfile
import scipy.io
import numpy as np
from scipy.fft import rfft, rfftfreq #real fft which only process the real portion of the fft result
import matplotlib.pyplot as plt
from scipy.fft import irfft


wav_fname = 'E01.wav'
samplerate, data = wavfile.read(wav_fname)
length = data.shape[0] / samplerate
time = np.linspace(0., length, data.shape[0])

wav_fname2 = 'E02.wav'
samplerate2, data2 = wavfile.read(wav_fname2)
length2 = data2.shape[0] / samplerate2
time2 = np.linspace(0., length2, data2.shape[0])

wav_fname3 = 'E03.wav'
samplerate3, data3 = wavfile.read(wav_fname3)
length3 = data3.shape[0] / samplerate3
time3 = np.linspace(0., length3, data3.shape[0])

wav_fname4 = 'E04.wav'
samplerate4, data4 = wavfile.read(wav_fname4)
length4 = data4.shape[0] / samplerate4
time4 = np.linspace(0., length4, data4.shape[0])

wav_fname5 = 'E05.wav'
samplerate5, data5 = wavfile.read(wav_fname5)
length5 = data5.shape[0] / samplerate5
time5 = np.linspace(0., length5, data5.shape[0])

wav_fname6 = 'problem.wav'
samplerate6, data6 = wavfile.read(wav_fname6)
length6 = data6.shape[0] / samplerate6
time6 = np.linspace(0., length6, data6.shape[0])

# Number of sample points
N = int(samplerate*length)
# sample spacing
T = 1.0 / samplerate

y = data
yf = rfft(y)
xf = rfftfreq(N, T)

N2= int(samplerate2*length2)
xf2 = rfftfreq(N2, 1.0/samplerate2)
y2 = data2
yf2 = rfft(y2)

N3= int(samplerate3*length3)
xf3 = rfftfreq(N3, 1.0/samplerate3)
y3 = data3
yf3 = rfft(y3)

N4= int(samplerate4*length4)
xf4 = rfftfreq(N4, 1.0/samplerate4)
y4 = data4
yf4 = rfft(y4)

N5= int(samplerate5*length5)
xf5 = rfftfreq(N5, 1.0/samplerate5)
y5 = data5
yf5 = rfft(y5)

N6 = int(samplerate6*length6)
xfp = rfftfreq(N6, 1.0/samplerate6)
y6 = data6
yf6 = rfft(y6)
    
yf6_abs      = np.abs(yf6) 
indices6     = yf6_abs>10000000   # filter out those value under 300
yf6_clean    = indices6 * yf6 # noise frequency will be set to 0

yf_abs      = np.abs(yf) 
indices     = yf_abs>10000000   # filter out those value under 300
yf_clean    = indices * yf # noise frequency will be set to 0

yf2_abs      = np.abs(yf2) 
indices2     = yf2_abs>10000000   # filter out those value under 300
yf2_clean    = indices2 * yf2 # noise frequency will be set to 0

yf3_abs      = np.abs(yf3) 
indices3     = yf3_abs>10000000   # filter out those value under 300
yf3_clean    = indices3 * yf3 # noise frequency will be set to 0

yf4_abs      = np.abs(yf4) 
indices4     = yf4_abs>10000000   # filter out those value under 300
yf4_clean    = indices4 * yf4 # noise frequency will be set to 0

yf5_abs      = np.abs(yf5) 
indices5     = yf5_abs>10000000   # filter out those value under 300
yf5_clean    = indices5 * yf5 # noise frequency will be set to 0

plt.xlim([160, 680])

plt.plot(xfp, np.abs(yf6_clean), label="problem")
plt.plot(xf, np.abs(yf_clean), label="E01")
plt.plot(xf2, np.abs(yf2_clean), label="E02")
plt.plot(xf3, np.abs(yf3_clean), label="E03")
plt.plot(xf4, np.abs(yf4_clean), label="E04")
plt.plot(xf5, np.abs(yf5_clean), label="E05")


plt.grid()
plt.legend()
plt.xlabel("frequency [Hz]")
plt.ylabel("Power")
plt.show()

# %%
new_f6_clean = irfft(yf6_clean)
new_f_clean = irfft(yf_clean)
new_f2_clean = irfft(yf2_clean)
new_f3_clean = irfft(yf3_clean)
new_f4_clean = irfft(yf4_clean)
new_f5_clean = irfft(yf5_clean)

plt.plot(time6,new_f6_clean, label="problem")
#plt.plot(time,new_f_clean, label="E01")
plt.plot(time2,new_f2_clean, label="E02")
plt.plot(time3,new_f3_clean, label="E03")
plt.plot(time4,new_f4_clean, label="E04")
#plt.plot(time5,new_f5_clean, label="E01")

plt.legend()
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
plt.show()

new_f_clean_resize = np.resize(new_f_clean.shape,new_f2_clean.shape)
new_f3_clean_resize = np.resize(new_f3_clean.shape,new_f2_clean.shape)
new_f4_clean_resize = np.resize(new_f4_clean.shape,new_f2_clean.shape)
new_f5_clean_resize = np.resize(new_f5_clean.shape,new_f2_clean.shape)

add = np.add(new_f_clean_resize,new_f2_clean)
add2 = np.add(new_f3_clean_resize,add)
add3 = np.add(new_f4_clean_resize,add)
add4 = np.add(new_f5_clean_resize,add)


write("try1.wav", samplerate, new_f6_clean.astype(np.int16))

# %%
#TRY USING SPEECH RECOGNITION

import speech_recognition as sr

# obtain path to "english.wav" in the same folder as this script
from os import path
AUDIO_FILE = "problem.wav"
# AUDIO_FILE = path.join(path.dirname(path.realpath(__file__)), "french.aiff")
# AUDIO_FILE = path.join(path.dirname(path.realpath(__file__)), "chinese.flac")

# use the audio file as the audio source
r = sr.Recognizer()
with sr.AudioFile(AUDIO_FILE) as source:
    audio = r.record(source)  # read the entire audio file

# recognize speech using Google Speech Recognition
try:
    # for testing purposes, we're just using the default API key
    # to use another API key, use `r.recognize_google(audio, key="GOOGLE_SPEECH_RECOGNITION_API_KEY")`
    # instead of `r.recognize_google(audio)`
    print("Google Speech Recognition thinks you said " + r.recognize_google(audio))
except sr.UnknownValueError:
    print("Google Speech Recognition could not understand audio")
except sr.RequestError as e:
    print("Could not request results from Google Speech Recognition service; {0}".format(e))

# %%
from os.path import dirname, join as pjoin
from scipy.io import wavfile
import scipy.io
import numpy as np
from scipy.fft import rfft, rfftfreq
import matplotlib.pyplot as plt

wav_fname = 'problem.wav'
samplerate, data = wavfile.read(wav_fname)
length = data.shape[0] / samplerate
time = np.linspace(0., length, data.shape[0])

wav_fname1 = 'problem1.wav'
samplerate1, data1 = wavfile.read(wav_fname1)
datas = data1.copy()
datas.resize(data.shape,refcheck=False)
length1 = datas.shape[0] / samplerate1
time1 = np.linspace(0., length1, datas.shape[0])

lengths = data1.shape[0] / samplerate1
times = np.linspace(0., lengths, data1.shape[0])

# Number of samples in normalized_tone 
N = int(samplerate1 * lengths) #problem 1
yf = rfft(data1)
xf = rfftfreq(N, 1 / samplerate1)

N1 = int(samplerate1 * length1) #problem 1 but shortened
yf1 = rfft(datas)
xf1 = rfftfreq(N1, 1 / samplerate1)

plt.xlim([20, 2000])

plt.plot(xf, np.abs(yf), label = "Q_E01")
plt.plot(xf1, np.abs(yf1), label = "Q_E01 but shortened")


plt.legend()
plt.xlabel("frequency [Hz]")
plt.ylabel("Power")
plt.show()

# %%
import matplotlib.pyplot as plt
from os.path import dirname
from scipy import signal
from scipy.io import wavfile

Fs, aud = wavfile.read('problem.wav')

powerSpectrum, frequenciesFound, time, imageAxis = plt.specgram(aud, Fs=Fs)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %%
Fs, aud = wavfile.read('E01.wav')

powerSpectrum, frequenciesFound, time, imageAxis = plt.specgram(aud, Fs=Fs)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %%
Fs, aud = wavfile.read('E02.wav')

powerSpectrum, frequenciesFound, time, imageAxis = plt.specgram(aud, Fs=Fs)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %%
#https://www.youtube.com/watch?v=m5LBYXIFHyY how to compare 2 files in python (result is percentage of similarity)

# %%
wav_fname = 'problem.wav'
samplerate, data = wavfile.read(wav_fname)
length = data.shape[0] / samplerate
time = np.linspace(0., length, data.shape[0])

wav_fname1 = 'problem1.wav'
samplerate1, data1 = wavfile.read(wav_fname1)
datas = data1.copy()
datas.resize(data.shape,refcheck=False)
length1 = datas.shape[0] / samplerate1
time1 = np.linspace(0., length1, datas.shape[0])

lengths = data1.shape[0] / samplerate1
times = np.linspace(0., lengths, data1.shape[0])

plt.plot(times, data1, label="Q_E01")
plt.plot(time1, datas, label="Q_E01 but shortened")


plt.legend()
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
plt.show()

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile

IN_WAVE_FILE = "Q_E01.wav"  # モノラル音声（前提）

FRAME_LENGTH = 1024  # フレーム長
HOP_LENGTH = 80  # フレームのシフト長

# 音声データ読み込み (fsがサンプリング周波数、dataは音声データ)
fs, data = wavfile.read(IN_WAVE_FILE)
data = data.astype(np.float64)

# 短時間フーリエ変換
data_stft = librosa.stft(data, hop_length=HOP_LENGTH, n_fft=FRAME_LENGTH)

# 振幅スペクトル
data_ampspec = np.abs(data_stft)

# 振幅スペクトルをデシベルスケールにする
data_ampspec_dB = librosa.amplitude_to_db(data_ampspec, ref=np.max)

# プロット枠を確保 (10がヨコのサイズ、4はタテのサイズ)
plt.figure(figsize=(10, 4))

# スペクトログラムの表示
librosa.display.specshow(
    data_ampspec_dB, x_axis="time", y_axis="linear", hop_length=HOP_LENGTH, sr=fs
)

# x軸のラベル
plt.xlabel("Time (sec)")

# y軸のラベル
plt.ylabel("Hz")

# 画像のタイトル
plt.title("Spectrogram")

# 余白を少なくする
plt.tight_layout()

# 画像を画面表示 (必須)
plt.show()
